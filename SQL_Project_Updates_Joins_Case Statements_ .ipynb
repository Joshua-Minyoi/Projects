# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # MAJODONGO SQL PART 2
#
# © ExploreAI Academy

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:joshua@localhost:3306/md_water_services
# Out:
# Connecting and switching to connection 'mysql+pymysql://root:***@localhost:3306/md_water_services'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line, then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     employee;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# +----------------------+----------------+--------------+-------------------------------+---------------------------+---------------+-----------+----------------+
# | assigned_employee_id | employee_name  | phone_number |             email             |          address          | province_name | town_name |    position    |
# +----------------------+----------------+--------------+-------------------------------+---------------------------+---------------+-----------+----------------+
# |          0           |  Amara Jengo   | +99637993287 |   amara.jengo@ndogowater.gov  |  36 Pwani Mchangani Road  |     Sokoto    |   Ilanga  | Field Surveyor |
# |          1           |  Bello Azibo   | +99643864786 |   bello.azibo@ndogowater.gov  |   129 Ziwa La Kioo Road   |    Kilimani   |   Rural   | Field Surveyor |
# ...

# %%
# %%sql
#
# select
#  replace(employee_name, ' ', '.') --replacing space between names with fullstop
# from employee;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# +----------------------------------+
# | replace(employee_name, ' ', '.') |
# +----------------------------------+
# |           Amara.Jengo            |
# |           Bello.Azibo            |
# |           Bakari.Iniko           |
# |          Malachi.Mavuso          |
# |           Cheche.Buhle           |
# |          Zuriel.Matembo          |
# |           Deka.Osumare           |
# |          Lalitha.Kaburi          |
# |           Enitan.Zuri            |
# |            Farai.Nia             |
# +----------------------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# select
#  lower(replace(employee_name, ' ', '.')) --converting to small letters
# from employee;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# +-----------------------------------------+
# | lower(replace(employee_name, ' ', '.')) |
# +-----------------------------------------+
# |               amara.jengo               |
# |               bello.azibo               |
# |               bakari.iniko              |
# |              malachi.mavuso             |
# |               cheche.buhle              |
# |              zuriel.matembo             |
# |               deka.osumare              |
# |              lalitha.kaburi             |
# |               enitan.zuri               |
# |                farai.nia                |
# +-----------------------------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# select
#  concat(
#  lower(replace(employee_name, ' ', '.')), '@ndogowater.gov') as new_email --concatination the remaining email address
# from employee; --adding the final emai address using cancatination
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# +-------------------------------+
# |           new_email           |
# +-------------------------------+
# |   amara.jengo@ndogowater.gov  |
# |   bello.azibo@ndogowater.gov  |
# |  bakari.iniko@ndogowater.gov  |
# | malachi.mavuso@ndogowater.gov |
# |  cheche.buhle@ndogowater.gov  |
# | zuriel.matembo@ndogowater.gov |
# |  deka.osumare@ndogowater.gov  |
# | lalitha.kaburi@ndogowater.gov |
# |   enitan.zuri@ndogowater.gov  |
# |    farai.nia@ndogowater.gov   |
# +-------------------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# update employee
# set email = concat(lower(replace(employee_name, ' ', '.')), '@ndogowater.gov'); --updating employee emails
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# The previous query may return a large number of rows, which could slow down our system. Modify the query to limit the number of rows returned to 10.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     employee; --checking emails have been updated
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# +----------------------+----------------+---------------+-------------------------------+---------------------------+---------------+-----------+----------------+
# | assigned_employee_id | employee_name  |  phone_number |             email             |          address          | province_name | town_name |    position    |
# +----------------------+----------------+---------------+-------------------------------+---------------------------+---------------+-----------+----------------+
# |          0           |  Amara Jengo   | +99637993287  |   amara.jengo@ndogowater.gov  |  36 Pwani Mchangani Road  |     Sokoto    |   Ilanga  | Field Surveyor |
# |          1           |  Bello Azibo   | +99643864786  |   bello.azibo@ndogowater.gov  |   129 Ziwa La Kioo Road   |    Kilimani   |   Rural   | Field Surveyor |
# ...

# %%
# %%sql
#
# select
#  length(phone_number)
# from
#  employee;--checking number of phone number characters
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# +----------------------+
# | length(phone_number) |
# +----------------------+
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# +----------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# The previous query may return a large number of rows, which could slow down our system. Modify the query to limit the number of rows returned to 10.

# %%
# %%sql
# select
#  trim(phone_number) as new_phone_number
# from employee
# limit 10;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 10 rows affected.
# +------------------+
# | new_phone_number |
# +------------------+
# |   +99637993287   |
# |   +99643864786   |
# |   +99222599041   |
# |   +99945849900   |
# |   +99381679640   |
# |   +99034075111   |
# |   +99379364631   |
# |   +99681623240   |
# |   +99248509202   |
# |   +99570082739   |
# +------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# select
#  length(phone_number)
# from employee;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# +----------------------+
# | length(phone_number) |
# +----------------------+
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# |          13          |
# +----------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Create a new table called `Country_list` and save the unique country names into this table.

# %%
# %%sql
#
# UPDATE employee
# SET phone_number = TRIM(REPLACE(phone_number, ' ', ''));---updating phone numbers
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# select
#  length(phone_number)
# from
#  employee;---checking the length is now 12
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 56 rows affected.
# +----------------------+
# | length(phone_number) |
# +----------------------+
# |          12          |
# |          12          |
# |          12          |
# |          12          |
# |          12          |
# |          12          |
# |          12          |
# |          12          |
# |          12          |
# |          12          |
# +----------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# The previous query may return a large number of rows, which could slow down our system. Modify the query to limit the number of rows returned to 10.

# %%
# %%sql
#
# SELECT town_name, COUNT(*) AS Num_Employees
# FROM employee
# GROUP BY town_name; --Grouping employees by town
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 9 rows affected.
# +-----------+---------------+
# | town_name | Num_Employees |
# +-----------+---------------+
# |   Ilanga  |       3       |
# |   Rural   |       29      |
# |   Lusaka  |       4       |
# |  Zanzibar |       4       |
# |   Dahabu  |       6       |
# |  Kintampo |       1       |
# |   Harare  |       5       |
# |  Yaounde  |       1       |
# |   Serowe  |       3       |
# +-----------+---------------+

# %%
# %%sql
#
# select *
# from visits;---just checking the visits table
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 60146 rows affected.
# +-----------+-------------+--------------+---------------------+-------------+---------------+----------------------+
# | record_id | location_id |  source_id   |    time_of_record   | visit_count | time_in_queue | assigned_employee_id |
# +-----------+-------------+--------------+---------------------+-------------+---------------+----------------------+
# |     0     |  SoIl32582  | SoIl32582224 | 2021-01-01 09:10:00 |      1      |       15      |          12          |
# |     1     |  KiRu28935  | KiRu28935224 | 2021-01-01 09:17:00 |      1      |       0       |          46          |
# |     2     |  HaRu19752  | HaRu19752224 | 2021-01-01 09:36:00 |      1      |       62      |          40          |
# |     3     |  AkLu01628  | AkLu01628224 | 2021-01-01 09:53:00 |      1      |       0       |          1           |
# ...

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>

# %%
# %%sql
#
# select assigned_employee_id, count(*) num_visits
# from visits
# group by assigned_employee_id;--grouping visits by employee
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 29 rows affected.
# +----------------------+------------+
# | assigned_employee_id | num_visits |
# +----------------------+------------+
# |          0           |    1099    |
# |          1           |    3708    |
# |          2           |    2033    |
# |          3           |    3420    |
# |          4           |    1136    |
# |          5           |    3284    |
# |          6           |    1182    |
# |          7           |    1259    |
# |          8           |    3351    |
# |          10          |    3407    |
# +----------------------+------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# select assigned_employee_id, count(*) num_visits
# from visits
# group by assigned_employee_id
# limit 3; --grouping visits by employee
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 3 rows affected.
# +----------------------+------------+
# | assigned_employee_id | num_visits |
# +----------------------+------------+
# |          0           |    1099    |
# |          1           |    3708    |
# |          2           |    2033    |
# +----------------------+------------+

# %%
# %%sql
#
# select assigned_employee_id, count(*) num_visits
# from visits
# group by assigned_employee_id
# order by num_visits asc;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 29 rows affected.
# +----------------------+------------+
# | assigned_employee_id | num_visits |
# +----------------------+------------+
# |          20          |     15     |
# |          22          |    143     |
# |          44          |    218     |
# |          26          |    719     |
# |          16          |    802     |
# |          0           |    1099    |
# |          4           |    1136    |
# |          6           |    1182    |
# |          7           |    1259    |
# |          14          |    1441    |
# +----------------------+------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# select employee_name
# from employee
# where assigned_employee_id in ('22','20');
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 2 rows affected.
# +---------------+
# | employee_name |
# +---------------+
# |   Kunto Asha  |
# |  Lesedi Kofi  |
# +---------------+

# %%
# %%sql
#
#
# SELECT
#     location_id,
#     time_in_queue,
#     AVG(time_in_queue) OVER (PARTITION BY location_id ORDER BY visit_count) AS total_avg_queue_time
# FROM
#     visits
# WHERE
# visit_count > 1 -- Only shared taps were visited > 1
# ORDER BY
#     location_id, time_of_record;----getting context on what this query does so that we answer the MCQ
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 20496 rows affected.
# +-------------+---------------+----------------------+
# | location_id | time_in_queue | total_avg_queue_time |
# +-------------+---------------+----------------------+
# |  AkHa00036  |      113      |       113.0000       |
# |  AkHa00036  |      229      |       171.0000       |
# |  AkHa00036  |      400      |       247.3333       |
# |  AkHa00036  |      120      |       215.5000       |
# |  AkHa00036  |      185      |       209.4000       |
# |  AkHa00036  |      158      |       200.8333       |
# |  AkHa00036  |      226      |       204.4286       |
# |  AkHa00090  |       50      |       50.0000        |
# |  AkHa00090  |       63      |       56.5000        |
# |  AkHa00090  |       12      |       41.6667        |
# +-------------+---------------+----------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# SELECT COUNT(*) AS employees_count
# FROM employee
# WHERE town_name = 'Dahabu';--number of employees that live in Dahabu
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 1 rows affected.
# +-----------------+
# | employees_count |
# +-----------------+
# |        6        |
# +-----------------+

# %%
# %%sql
#
# SELECT COUNT(*) AS employees_count
# FROM employee
# WHERE town_name = 'Harare' and province_name = 'kilimani';---kilimani and Harare, both must be true since we used AND condition
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 1 rows affected.
# +-----------------+
# | employees_count |
# +-----------------+
# |        2        |
# +-----------------+

# %%
# %%sql
#
#
# SELECT
#     ROUND(AVG(number_of_people_served), 0) AS population_served
# FROM
#     water_source
# WHERE
#     type_of_water_source = 'well';-- those served by a well, rounded to 0 decimal
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 1 rows affected.
# +-------------------+
# | population_served |
# +-------------------+
# |        279        |
# +-------------------+

# %%
# %%sql
#
# SELECT
#     type_of_water_source,
#     COUNT(*) AS count_of_sources,
#     AVG(CASE
#             WHEN type_of_water_source LIKE '%tap%' THEN number_of_people_served / 6.0
#             ELSE number_of_people_served
#         END) AS avg_people_served,
#     SUM(number_of_people_served) AS sum_people_served,
#     ROUND((SUM(number_of_people_served) / (SELECT SUM(number_of_people_served) FROM md_water_services.water_source)) * 100) AS Pct_of_people_served_per_source,
#     RANK() OVER (ORDER BY SUM(number_of_people_served) DESC) AS rank_by_population
# FROM
#     md_water_services.water_source
# GROUP BY
#     type_of_water_source
# ORDER BY
#     sum_people_served DESC;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 5 rows affected.
# +----------------------+------------------+-------------------+-------------------+---------------------------------+--------------------+
# | type_of_water_source | count_of_sources | avg_people_served | sum_people_served | Pct_of_people_served_per_source | rank_by_population |
# +----------------------+------------------+-------------------+-------------------+---------------------------------+--------------------+
# |      shared_tap      |       5767       |    345.21912018   |      11945272     |                43               |         1          |
# |         well         |      17383       |    278.53212909   |      4841724      |                18               |         2          |
# |     tap_in_home      |       7265       |    107.33838000   |      4678880      |                17               |         3          |
# ...

# %%
# %%sql
#
# SELECT CONCAT(day(time_of_record), " ", monthname(time_of_record), " ", year(time_of_record)) FROM visits;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 60146 rows affected.
# +----------------------------------------------------------------------------------------+
# | CONCAT(day(time_of_record), " ", monthname(time_of_record), " ", year(time_of_record)) |
# +----------------------------------------------------------------------------------------+
# |                                     1 January 2021                                     |
# |                                     1 January 2021                                     |
# |                                     1 January 2021                                     |
# |                                     1 January 2021                                     |
# |                                     1 January 2021                                     |
# |                                     1 January 2021                                     |
# ...

# %%
# %%sql
#
# UPDATE
# well_pollution
# SET
# description = 'Bacteria:E. coli'
# WHERE description = 'Clean Bacteria:E. coli';
# UPDATE
# well_pollution
# SET
# description = 'Bacteria: Giardia Lamblia'
# WHERE
# description = 'Clean Bacteria: Giardia Lamblia';
# UPDATE
# well_pollution
# SET
# results = 'Contaminated: Biological'
# WHERE
# biological > 0.01 AND results = 'Clean'; ---updating the well_polution table
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 12 rows affected.
# 64 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# show tables;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 10 rows affected.
# +-----------------------------+
# | Tables_in_md_water_services |
# +-----------------------------+
# |        auditor_report       |
# |       data_dictionary       |
# |           employee          |
# |     global_water_access     |
# |           location          |
# |            visits           |
# |        water_quality        |
# |         water_source        |
# |        well_pollution       |
# |     well_pollution_copy     |
# +-----------------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# SELECT province_name, town_name, visit_count, location.location_id
# FROM location
# INNER JOIN visits
#     ON location.location_id = visits.location_id;  ----Joining tables
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 60146 rows affected.
# +---------------+-----------+-------------+-------------+
# | province_name | town_name | visit_count | location_id |
# +---------------+-----------+-------------+-------------+
# |     Akatsi    |   Harare  |      1      |  AkHa00000  |
# |     Akatsi    |   Harare  |      1      |  AkHa00001  |
# |     Akatsi    |   Harare  |      1      |  AkHa00002  |
# |     Akatsi    |   Harare  |      1      |  AkHa00003  |
# |     Akatsi    |   Harare  |      1      |  AkHa00004  |
# |     Akatsi    |   Harare  |      1      |  AkHa00005  |
# |     Akatsi    |   Harare  |      1      |  AkHa00006  |
# |     Akatsi    |   Harare  |      1      |  AkHa00007  |
# |     Akatsi    |   Harare  |      1      |  AkHa00008  |
# |     Akatsi    |   Harare  |      1      |  AkHa00009  |
# +---------------+-----------+-------------+-------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# SELECT
#     location.province_name,
#     location.town_name,
#     visits.visit_count,
#     location.location_id,
#     water_source.source_id,
#     water_source.number_of_people_served
# FROM
#     location
# INNER JOIN
#     visits ON location.location_id = visits.location_id
# INNER JOIN
#     water_source ON visits.source_id = water_source.source_id;                        ---Joining all tables
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 60146 rows affected.
# +---------------+-----------+-------------+-------------+--------------+-------------------------+
# | province_name | town_name | visit_count | location_id |  source_id   | number_of_people_served |
# +---------------+-----------+-------------+-------------+--------------+-------------------------+
# |     Akatsi    |   Harare  |      1      |  AkHa00000  | AkHa00000224 |           956           |
# |     Akatsi    |   Harare  |      1      |  AkHa00001  | AkHa00001224 |           930           |
# |     Akatsi    |   Harare  |      1      |  AkHa00002  | AkHa00002224 |           486           |
# |     Akatsi    |   Harare  |      1      |  AkHa00003  | AkHa00003224 |           364           |
# |     Akatsi    |   Harare  |      1      |  AkHa00004  | AkHa00004224 |           942           |
# ...

# %%
# %%sql
#
# SELECT
#     location.province_name,
#     location.town_name,
#     visits.visit_count,
#     location.location_id,
#     water_source.source_id,
#     water_source.number_of_people_served
# FROM
#     location
# INNER JOIN
#     visits ON location.location_id = visits.location_id
# INNER JOIN
#     water_source ON visits.source_id = water_source.source_id
# WHERE visit_count > 1;                                     ---where visit count >1
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 20496 rows affected.
# +---------------+-----------+-------------+-------------+--------------+-------------------------+
# | province_name | town_name | visit_count | location_id |  source_id   | number_of_people_served |
# +---------------+-----------+-------------+-------------+--------------+-------------------------+
# |    Kilimani   |   Rural   |      2      |  KiRu30598  | KiRu30598224 |           462           |
# |     Sokoto    |   Rural   |      2      |  SoRu35008  | SoRu35008224 |           3746          |
# |    Hawassa    |   Rural   |      2      |  HaRu19752  | HaRu19752224 |           542           |
# |    Kilimani   |   Rural   |      2      |  KiRu27248  | KiRu27248224 |           2602          |
# |    Kilimani   |   Rural   |      2      |  KiRu26190  | KiRu26190224 |           2050          |
# ...

# %%
# %%sql
#
# SELECT
#     location.province_name,
#     location.town_name,
#     visits.visit_count,
#     location.location_id,
#     water_source.source_id,
#     water_source.number_of_people_served
# FROM
#     location
# INNER JOIN
#     visits ON location.location_id = visits.location_id
# INNER JOIN
#     water_source ON visits.source_id = water_source.source_id
# WHERE visits.location_id='AkHa00103';                      -----where location_id=AKHa00103
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 8 rows affected.
# +---------------+-----------+-------------+-------------+--------------+-------------------------+
# | province_name | town_name | visit_count | location_id |  source_id   | number_of_people_served |
# +---------------+-----------+-------------+-------------+--------------+-------------------------+
# |     Akatsi    |   Harare  |      1      |  AkHa00103  | AkHa00103224 |           3340          |
# |     Akatsi    |   Harare  |      2      |  AkHa00103  | AkHa00103224 |           3340          |
# |     Akatsi    |   Harare  |      3      |  AkHa00103  | AkHa00103224 |           3340          |
# |     Akatsi    |   Harare  |      4      |  AkHa00103  | AkHa00103224 |           3340          |
# |     Akatsi    |   Harare  |      5      |  AkHa00103  | AkHa00103224 |           3340          |
# ...

# %%
# %%sql
#
# SELECT
#     location.province_name,
#     location.town_name,
#     visits.visit_count,
#     location.location_id,
#     water_source.source_id,
#     water_source.number_of_people_served
# FROM
#     location
# INNER JOIN
#     visits ON location.location_id = visits.location_id
# INNER JOIN
#     water_source ON visits.source_id = water_source.source_id
# WHERE visits.visit_count=1;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 39650 rows affected.
# +---------------+-----------+-------------+-------------+--------------+-------------------------+
# | province_name | town_name | visit_count | location_id |  source_id   | number_of_people_served |
# +---------------+-----------+-------------+-------------+--------------+-------------------------+
# |     Sokoto    |   Ilanga  |      1      |  SoIl32582  | SoIl32582224 |           402           |
# |    Kilimani   |   Rural   |      1      |  KiRu28935  | KiRu28935224 |           252           |
# |    Hawassa    |   Rural   |      1      |  HaRu19752  | HaRu19752224 |           542           |
# |     Akatsi    |   Lusaka  |      1      |  AkLu01628  | AkLu01628224 |           210           |
# |     Akatsi    |   Rural   |      1      |  AkRu03357  | AkRu03357224 |           2598          |
# ...

# %%
# %%sql
#
# SELECT
#     location.province_name,
#     location.town_name,
#     water_source.source_id,
#     water_source.number_of_people_served
# FROM
#     location
# INNER JOIN
#     visits ON location.location_id = visits.location_id
# INNER JOIN
#     water_source ON visits.source_id = water_source.source_id
# WHERE visits.visit_count=1;                                   -----removed the visit_count and location_id column
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 39650 rows affected.
# +---------------+-----------+--------------+-------------------------+
# | province_name | town_name |  source_id   | number_of_people_served |
# +---------------+-----------+--------------+-------------------------+
# |     Sokoto    |   Ilanga  | SoIl32582224 |           402           |
# |    Kilimani   |   Rural   | KiRu28935224 |           252           |
# |    Hawassa    |   Rural   | HaRu19752224 |           542           |
# |     Akatsi    |   Lusaka  | AkLu01628224 |           210           |
# |     Akatsi    |   Rural   | AkRu03357224 |           2598          |
# |    Kilimani   |   Rural   | KiRu29315224 |           862           |
# |     Akatsi    |   Rural   | AkRu05234224 |           496           |
# |    Kilimani   |   Rural   | KiRu28520224 |           562           |
# |    Hawassa    |  Zanzibar | HaZa21742224 |           308           |
# ...

# %%
# %%sql
#
# SELECT
#     location.province_name,
#     location.town_name,
#     water_source.type_of_water_source,
#     location.location_type,
#     water_source.number_of_people_served,
#     visits.time_in_queue
# FROM
#     location
# INNER JOIN
#     visits ON location.location_id = visits.location_id
# INNER JOIN
#     water_source ON visits.source_id = water_source.source_id
# WHERE visits.visit_count=1;                                           -----verified that joins are working and added time_in_queue column
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 39650 rows affected.
# +---------------+-----------+----------------------+---------------+-------------------------+---------------+
# | province_name | town_name | type_of_water_source | location_type | number_of_people_served | time_in_queue |
# +---------------+-----------+----------------------+---------------+-------------------------+---------------+
# |     Sokoto    |   Ilanga  |        river         |     Urban     |           402           |       15      |
# |    Kilimani   |   Rural   |         well         |     Rural     |           252           |       0       |
# |    Hawassa    |   Rural   |      shared_tap      |     Rural     |           542           |       62      |
# |     Akatsi    |   Lusaka  |         well         |     Urban     |           210           |       0       |
# ...

# %%
# %%sql
# SELECT
# water_source.type_of_water_source,
# location.town_name,
# location.province_name,
# location.location_type,
# water_source.number_of_people_served,
# visits.time_in_queue,
# well_pollution.results
# FROM
# visits
# LEFT JOIN
# well_pollution
# ON well_pollution.source_id = visits.source_id
# INNER JOIN
# location
# ON location.location_id = visits.location_id
# INNER JOIN
# water_source
# ON water_source.source_id = visits.source_id
# WHERE
# visits.visit_count = 1;                               --- This table assembles data from different tables into one to simplify analysis
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 39650 rows affected.
# +----------------------+-----------+---------------+---------------+-------------------------+---------------+--------------------------+
# | type_of_water_source | town_name | province_name | location_type | number_of_people_served | time_in_queue |         results          |
# +----------------------+-----------+---------------+---------------+-------------------------+---------------+--------------------------+
# |        river         |   Ilanga  |     Sokoto    |     Urban     |           402           |       15      |           None           |
# |         well         |   Rural   |    Kilimani   |     Rural     |           252           |       0       | Contaminated: Biological |
# |      shared_tap      |   Rural   |    Hawassa    |     Rural     |           542           |       62      |           None           |
# ...

# %%
# %%sql
#
# CREATE VIEW combined_analysis_table AS
# SELECT
# water_source.type_of_water_source AS source_type,
# location.town_name,
# location.province_name,
# location.location_type,
# water_source.number_of_people_served AS people_served,
# visits.time_in_queue,
# well_pollution.results
# FROM
# visits
# LEFT JOIN
# well_pollution
# ON well_pollution.source_id = visits.source_id
# INNER JOIN
# location
# ON location.location_id = visits.location_id
# INNER JOIN
# water_source
# ON water_source.source_id = visits.source_id
# WHERE
# visits.visit_count = 1;                                     ---This view assembles data from different tables into one to simplify analysis
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %%sql
#
# WITH province_totals AS (---This CTE calculates the population of each province
# SELECT
# province_name,
# SUM(people_served) AS total_ppl_serv
# FROM
# combined_analysis_table
# GROUP BY
# province_name
# )
# SELECT
# ct.province_name,
# ---- These case statements create columns for each type of source.
# ---The results are aggregated and percentages are calculated
# ROUND((SUM(CASE WHEN source_type = 'river'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS river,
# ROUND((SUM(CASE WHEN source_type = 'shared_tap'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS shared_tap,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS tap_in_home,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home_broken'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS tap_in_home_broken,
# ROUND((SUM(CASE WHEN source_type = 'well'
# THEN people_served ELSE 0 END) * 100.0 / pt.total_ppl_serv), 0) AS well
# FROM
# combined_analysis_table ct
# JOIN
# province_totals pt ON ct.province_name = pt.province_name
# GROUP BY
# ct.province_name
# ORDER BY
# ct.province_name;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 5 rows affected.
# +---------------+-------+------------+-------------+--------------------+------+
# | province_name | river | shared_tap | tap_in_home | tap_in_home_broken | well |
# +---------------+-------+------------+-------------+--------------------+------+
# |     Akatsi    |   5   |     49     |      14     |         10         |  23  |
# |     Amanzi    |   3   |     38     |      28     |         24         |  7   |
# |    Hawassa    |   4   |     43     |      15     |         15         |  24  |
# |    Kilimani   |   8   |     47     |      13     |         12         |  20  |
# |     Sokoto    |   21  |     38     |      16     |         10         |  15  |
# +---------------+-------+------------+-------------+--------------------+------+

# %%
# %%sql
#
# WITH town_totals AS (--- This CTE calculates the population of each town
# ---Since there are two Harare towns, we have to group by province_name and town_name
# SELECT province_name, town_name, SUM(people_served) AS total_ppl_serv
# FROM combined_analysis_table
# GROUP BY province_name,town_name
# )
# SELECT
# ct.province_name,
# ct.town_name,
# ROUND((SUM(CASE WHEN source_type = 'river'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS river,
# ROUND((SUM(CASE WHEN source_type = 'shared_tap'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS shared_tap,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS tap_in_home,
# ROUND((SUM(CASE WHEN source_type = 'tap_in_home_broken'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS tap_in_home_broken,
# ROUND((SUM(CASE WHEN source_type = 'well'
# THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS well
# FROM
# combined_analysis_table ct
# JOIN --- Since the town names are not unique, we have to join on a composite key
# town_totals tt ON ct.province_name = tt.province_name AND ct.town_name = tt.town_name
# GROUP BY --- We group by province first, then by town.
# ct.province_name,
# ct.town_name
# ORDER BY
# tap_in_home desc;   -----This shows the towns with most drinking river water
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 31 rows affected.
# +---------------+-----------+-------+------------+-------------+--------------------+------+
# | province_name | town_name | river | shared_tap | tap_in_home | tap_in_home_broken | well |
# +---------------+-----------+-------+------------+-------------+--------------------+------+
# |     Amanzi    |   Dahabu  |   3   |     37     |      55     |         1          |  4   |
# |     Sokoto    |   Ilanga  |   16  |     12     |      36     |         15         |  21  |
# |     Sokoto    |   Bahari  |   21  |     11     |      36     |         12         |  20  |
# |     Sokoto    |  Majengo  |   18  |     14     |      36     |         12         |  20  |
# |     Sokoto    |   Cheche  |   19  |     16     |      35     |         12         |  18  |
# |     Sokoto    |    Kofi   |   20  |     16     |      34     |         10         |  20  |
# ...

# %%
# %%sql
#
# SELECT
# province_name,
# town_name,
# ROUND(tap_in_home_broken / (tap_in_home_broken + tap_in_home) *
# 100,0) AS Pct_broken_taps
# FROM
# town_aggregated_water_access;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 31 rows affected.
# +---------------+-----------+-----------------+
# | province_name | town_name | Pct_broken_taps |
# +---------------+-----------+-----------------+
# |     Amanzi    |  Abidjan  |        46       |
# |    Kilimani   |   Amara   |        39       |
# |     Amanzi    |   Amina   |        95       |
# |    Hawassa    |   Amina   |        56       |
# |     Amanzi    |   Asmara  |        45       |
# |     Sokoto    |   Bahari  |        25       |
# |     Amanzi    |   Bello   |        52       |
# |     Sokoto    |   Cheche  |        26       |
# |     Amanzi    |   Dahabu  |        2        |
# |    Hawassa    |    Deka   |        48       |
# +---------------+-----------+-----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
#
# WITH town_totals AS (
#     -- This CTE calculates the total population served in each town
#     -- Since there are two Harare towns, we have to group by province_name and town_name
#     SELECT
#         province_name,
#         town_name,
#         SUM(people_served) AS total_ppl_serv
#     FROM
#         combined_analysis_table
#     GROUP BY
#         province_name, town_name
# )
# SELECT
#     ct.province_name,
#     ct.town_name,
#     -- Calculate the percentage of people served by 'river' and round to 0 decimal places
#     ROUND((SUM(CASE WHEN source_type = 'river'
#                     THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS river,
#     -- Calculate the percentage of people served by 'shared_tap' and round to 0 decimal places
#     ROUND((SUM(CASE WHEN source_type = 'shared_tap'
#                     THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS shared_tap,
#     -- Calculate the percentage of people served by 'tap_in_home' and round to 0 decimal places
#     ROUND((SUM(CASE WHEN source_type = 'tap_in_home'
#                     THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS tap_in_home,
#     -- Calculate the percentage of people served by 'tap_in_home_broken' and round to 0 decimal places
#     ROUND((SUM(CASE WHEN source_type = 'tap_in_home_broken'
#                     THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS tap_in_home_broken,
#     -- Calculate the percentage of people served by 'well' and round to 0 decimal places
#     ROUND((SUM(CASE WHEN source_type = 'well'
#                     THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) AS well
# FROM
#     combined_analysis_table ct
# JOIN
#     town_totals tt
# ON
#     ct.province_name = tt.province_name AND ct.town_name = tt.town_name
# GROUP BY
#     ct.province_name, ct.town_name
# HAVING
#     ROUND((SUM(CASE WHEN source_type = 'tap_in_home'
#                     THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) < 50
#     AND
#     ROUND((SUM(CASE WHEN source_type = 'tap_in_home_broken'
#                     THEN people_served ELSE 0 END) * 100.0 / tt.total_ppl_serv), 0) < 50
# ORDER BY
#     river DESC;
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %config SqlMagic.displaylimit=1000;

# %%
# %%sql
#
# SELECT
# project_progress.Project_id,
# project_progress.Town,
# project_progress.Province,
# project_progress.Source_type,
# project_progress.Improvement,
# Water_source.number_of_people_served,
# RANK() OVER(PARTITION BY Province ORDER BY number_of_people_served)
# FROM  project_progress
# JOIN water_source
# ON water_source.source_id = project_progress.source_id
# WHERE Improvement = "Drill Well"
# ORDER BY Province DESC, number_of_people_served;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (pymysql.err.ProgrammingError) (1146, "Table 'md_water_services.project_progress' doesn't exist")
# [SQL: SELECT
# project_progress.Project_id,
# project_progress.Town,
# project_progress.Province,
# project_progress.Source_type,
# project_progress.Improvement,
# Water_source.number_of_people_served,
# RANK() OVER(PARTITION BY Province ORDER BY number_of_people_served)
# FROM  project_progress
# JOIN water_source
# ON water_source.source_id = project_progress.source_id
# WHERE Improvement = "Drill Well"
# ORDER BY Province DESC, number_of_people_served;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# ...

# %%
# %%sql
#
# show tables ;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 11 rows affected.
# +-----------------------------+
# | Tables_in_md_water_services |
# +-----------------------------+
# |        auditor_report       |
# |   combined_analysis_table   |
# |       data_dictionary       |
# |           employee          |
# |     global_water_access     |
# |           location          |
# |            visits           |
# |        water_quality        |
# |         water_source        |
# |        well_pollution       |
# |     well_pollution_copy     |
# +-----------------------------+

# %%
# %sql
CREATE TABLE Project_progress (
Project_id SERIAL PRIMARY KEY,
/* Project_id −− Unique key for sources in case we visit the same
source more than once in the future.
*/
source_id VARCHAR(20) NOT NULL REFERENCES water_source(source_id) ON DELETE CASCADE ON UPDATE CASCADE,
/* source_id −− Each of the sources we want to improve should exist,
and should refer to the source table. This ensures data integrity.
*/
Address VARCHAR(50), −− Street address
Town VARCHAR(30),
Province VARCHAR(30),
Source_type VARCHAR(50),
Improvement VARCHAR(50), −− What the engineers should do at that place
Source_status VARCHAR(50) DEFAULT 'Backlog' CHECK (Source_status IN ('Backlog', 'In progress', 'Complete')),
/* Source_status −− We want to limit the type of information engineers can give us, so we
limit Source_status.
− By DEFAULT all projects are in the "Backlog" which is like a TODO list.
− CHECK() ensures only those three options will be accepted. This helps to maintain clean data.
*/
Date_of_completion DATE, −− Engineers will add this the day the source has been upgraded.
Comments TEXT −− Engineers can leave comments. We use a TEXT type that has no limit on char length
);
# Out:
#   Cell In[55], line 4
#     /* Project_id −− Unique key for sources in case we visit the same
#                   ^
# SyntaxError: invalid character '−' (U+2212)

# %%
# %%sql
#
# CREATE TABLE Project_progress (
#     Project_id SERIAL PRIMARY KEY,
#     source_id VARCHAR(20) NOT NULL REFERENCES water_source(source_id) ON DELETE CASCADE ON UPDATE CASCADE,
#     Address VARCHAR(50),
#     Town VARCHAR(30),
#     Province VARCHAR(30),
#     Source_type VARCHAR(50),
#     Improvement VARCHAR(50),
#     Source_status VARCHAR(50) DEFAULT 'Backlog' CHECK (Source_status IN ('Backlog', 'In progress', 'Complete')),
#     Date_of_completion DATE,
#     Comments TEXT
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT
#     location.address,
#     location.town_name,
#     location.province_name,
#     water_source.source_id,
#     water_source.type_of_water_source,
#     well_pollution.results
# FROM
#     water_source
# LEFT JOIN
#     well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
#     visits ON water_source.source_id = visits.source_id
# INNER JOIN
#     location ON location.location_id = visits.location_id
# WHERE
#     visits.visit_count = 1
# AND (
#     well_pollution.results != 'Clean'
#     OR water_source.type_of_water_source IN ('tap_in_home_broken', 'tap_in_home')
#     OR (water_source.type_of_water_source = 'shared_tap' AND well_pollution.results != 'Clean')
# );
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 25588 rows affected.
# Deploy Flask apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup
# +----------------------------------+-----------+---------------+--------------+----------------------+--------------------------+
# |             address              | town_name | province_name |  source_id   | type_of_water_source |         results          |
# +----------------------------------+-----------+---------------+--------------+----------------------+--------------------------+
# |      129 Ziwa La Kioo Road       |   Rural   |    Kilimani   | KiRu28935224 |         well         | Contaminated: Biological |
# |        100 Mogadishu Road        |   Lusaka  |     Akatsi    | AkLu01628224 |         well         | Contaminated: Biological |
# |       104 Kenyatta Street        |   Rural   |     Akatsi    | AkRu05234224 |  tap_in_home_broken  |           None           |
# ...

# %%
# %%sql
#
# SELECT
#     location.address,
#     location.town_name,
#     location.province_name,
#     water_source.source_id,
#     water_source.type_of_water_source,
#     well_pollution.results
# FROM
#     water_source
# LEFT JOIN
#     well_pollution ON water_source.source_id = well_pollution.source_id
# INNER JOIN
#     visits ON water_source.source_id = visits.source_id
# INNER JOIN
#     location ON location.location_id = visits.location_id
# WHERE
#     visits.visit_count = 1
# AND water_source.type_of_water_source = 'well'
# AND well_pollution.results = 'Contaminated: Biological';
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/md_water_services'
# 5374 rows affected.
# +----------------------------------+-----------+---------------+--------------+----------------------+--------------------------+
# |             address              | town_name | province_name |  source_id   | type_of_water_source |         results          |
# +----------------------------------+-----------+---------------+--------------+----------------------+--------------------------+
# |      129 Ziwa La Kioo Road       |   Rural   |    Kilimani   | KiRu28935224 |         well         | Contaminated: Biological |
# |        100 Mogadishu Road        |   Lusaka  |     Akatsi    | AkLu01628224 |         well         | Contaminated: Biological |
# |         52 Moroni Avenue         |   Rural   |     Sokoto    | SoRu35703224 |         well         | Contaminated: Biological |
# ...
